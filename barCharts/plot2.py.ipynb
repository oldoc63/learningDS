# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("games.csv")

# %%
sns.countplot(x=df["victory_status"])
# Out:
# <AxesSubplot: xlabel='victory_status', ylabel='count'>

# %%
sns.countplot(x=df["victory_status"], order=df["victory_status"].value_counts(ascending=True).index)
# Out:
# <AxesSubplot: xlabel='victory_status', ylabel='count'>
